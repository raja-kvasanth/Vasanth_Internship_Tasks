# %%
# !pip install flask pyngrok

# %%
from flask import Flask, request
import re
from pyngrok import ngrok

app = Flask(__name__)

# %%
@app.route('/', methods=['GET', 'POST'])
def home():
    matches = []
    error = None

    if request.method == 'POST':
        test_string = request.form.get('test_string')
        regex = request.form.get('regex')

        try:
            matches = re.findall(regex, test_string)
        except re.error:
            error = "Invalid Regular Expression"

    return f"""
    <html>
    <head>
        <title>Regex Matcher</title>
    </head>
    <body style="font-family:Arial; padding:30px;">
        <h2>Regex101 Clone</h2>

        <form method="POST">
            <label>Test String:</label><br>
            <textarea name="test_string" rows="4" cols="60"></textarea><br><br>

            <label>Regular Expression:</label><br>
            <input type="text" name="regex" size="60"><br><br>

            <button type="submit">Submit</button>
        </form>

        <hr>

        <h3>Matches:</h3>
        {matches if matches else "No matches found"}

        <p style="color:red;">{error if error else ""}</p>
    </body>
    </html>
    """

# %%
ngrok.set_auth_token("3849aq7oMilBPYk1KGOmmgnpHq_4twiCVrGpivRREYwExE5W")

# %%
public_url = ngrok.connect(5000)
print("Public URL:", public_url)
# Out:
# Public URL: NgrokTunnel: "https://directional-superaffluently-ayako.ngrok-free.dev" -> "http://localhost:5000"

# %%
app.run(port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [19/Jan/2026 14:16:21] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Jan/2026 14:16:22] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Jan/2026 14:17:03] "POST / HTTP/1.1" 200 -
# WARNING:pyngrok.process.ngrok:t=2026-01-19T14:17:27+0000 lvl=warn msg="Stopping forwarder" name=http-5000-d211a4a3-e8de-4f58-8b6d-20ed7b7e6800 acceptErr="failed to accept connection: Listener closed"
