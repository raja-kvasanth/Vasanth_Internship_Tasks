# %%
# !pip install flask pyngrok

# %%
from flask import Flask, request
from pyngrok import ngrok

app = Flask(__name__)

@app.route('/')
def home():
    name = request.args.get('name')
    if name:
        return f"<h1>Hello, {name.upper()} 👋</h1>"
    return "<h2>Use ?name=vasanth</h2>"

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3849aq7oMilBPYk1KGOmmmgnpHq_4twiCVrGpivRREYwExE5W")

# %%
public_url = ngrok.connect(5000)
print("Public URL:", public_url)
# Out:
# Public URL: NgrokTunnel: "https://directional-superaffluently-ayako.ngrok-free.dev" -> "http://localhost:5000"

# %%
@app.route('/fancy')
def fancy():
    name = request.args.get('name')
    if name:
        return f"""
        <div style='text-align:center; font-size:30px; color:purple'>
            🌟 Welcome {name.upper()} 🌟
        </div>
        """
    return "<h2>Use ?name=vasanth</h2>"

# %%
app.run(port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [10/Jan/2026 12:45:38] "GET /?name=kaiju HTTP/1.1" 200 -
